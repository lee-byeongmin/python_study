# %% [markdown]
# 유산균같은 교강사 닥터윌과 함께하는
#
# ## 서울시에서 공개한 코로나19 발생동향 분석
# * http://www.seoul.go.kr/coronaV/coronaStatus.do

# %%
# pandas, numpy 라이브러리 로드
import pandas as pd
import numpy as np

# %%
# file_name 변수에 read_html 로 저장한 파일명을 지정
url = "http://www.seoul.go.kr/coronaV/coronaStatus.do"
url
# Out:
# 'http://www.seoul.go.kr/coronaV/coronaStatus.do'

# %%
# 판다스의 read_html로 url 불러오기 
pd.read_html?

# %%
# 판다스의 read_html로 url 불러오기 
table = pd.read_html(url)
table
# Out:
# [   종로구   중구  용산구  성동구  광진구  동대문구  중랑구  성북구  강북구  도봉구  노원구  은평구 서대문구
#  0   44   35   76   74   52    86   89  183   65  104  107  116   56
#  1  마포구  양천구  강서구  구로구  금천구  영등포구  동작구  관악구  서초구  강남구  송파구  강동구   기타
#  2   84   92  151  108   46    86  102  170  102  129  171   83  210,
#      종로구   중구  용산구  성동구  광진구 동대문구
#  0    44   35   76   74   52   86
#  1   중랑구  성북구  강북구  도봉구  노원구  은평구
#  2    89  183   65  104  107  116
#  3  서대문구  마포구  양천구  강서구  구로구  금천구
#  4    56   84   92  151  108   46
#  5  영등포구  동작구  관악구  서초구  강남구  송파구
#  6    86  102  170  102  129  171
#  7   강동구   기타  NaN  NaN  NaN  NaN
#  8    83  210  NaN  NaN  NaN  NaN,
#       소계  해외접촉관련  성북구사랑제일교회  용인시우리제일교회  양천구되새김교회  노원구안디옥교회  여의도순복음교회  광화문집회관련  \
#  0  2621     378        432         57        11        20         4       26
#
#     고양시반석교회(케네디상가)  강서구요양시설관련  리치웨이관련  이태원클럽관련  구로구콜센터관련  타 시·도확진자접촉자   기타  \
#  0              11         26     119      139        98           78  884
#
#     경로확인중
#  0    338  ,
# ...

# %%
# 전체 table 갯수 확인
len(table)
# Out:
# 8

# %%
# read_html은 사이트 내 html 태그를 불러옴 
table[0]
# Out:
#    종로구   중구  용산구  성동구  광진구  동대문구  중랑구  성북구  강북구  도봉구  노원구  은평구 서대문구
# 0   44   35   76   74   52    86   89  183   65  104  107  116   56
# 1  마포구  양천구  강서구  구로구  금천구  영등포구  동작구  관악구  서초구  강남구  송파구  강동구   기타
# 2   84   92  151  108   46    86  102  170  102  129  171   83  210

# %%
# read_html은 사이트 내 html 태그를 불러옴 
table[2]
# Out:
#      소계  해외접촉관련  성북구사랑제일교회  용인시우리제일교회  양천구되새김교회  노원구안디옥교회  여의도순복음교회  광화문집회관련  \
# 0  2621     378        432         57        11        20         4       26
#
#    고양시반석교회(케네디상가)  강서구요양시설관련  리치웨이관련  이태원클럽관련  구로구콜센터관련  타 시·도확진자접촉자   기타  \
# 0              11         26     119      139        98           78  884
#
#    경로확인중
# 0    338

# %%
# read_html은 사이트 내 html 태그를 불러옴 
table[2].T # transpose 전치
# Out:
#                    0
# 소계              2621
# 해외접촉관련           378
# 성북구사랑제일교회        432
# 용인시우리제일교회         57
# 양천구되새김교회          11
# 노원구안디옥교회          20
# 여의도순복음교회           4
# 광화문집회관련           26
# 고양시반석교회(케네디상가)    11
# 강서구요양시설관련         26
# 리치웨이관련           119
# 이태원클럽관련          139
# 구로구콜센터관련          98
# 타 시·도확진자접촉자       78
# 기타               884
# 경로확인중            338

# %%
table[6]
# Out:
#         연번     환자    확진일  거주지     여행력    접촉력         조치사항
# 0     2621  16421  8.20.  중랑구       -   확인 중          배정중
# 1     2620  16393  8.20.   기타       -   확인 중          배정중
# 2     2619  16633  8.20.  동작구       -   확인 중          배정중
# 3     2618    미부여  8.20.  종로구       -     기타          배정중
# 4     2617  16643  8.20.  강북구       -   확인 중          배정중
# ...    ...    ...    ...  ...     ...    ...          ...
# 2616     5      9  1.31.  성북구       -  #5 접촉    서울의료원(퇴원)
# 2617     4      7  1.30.  마포구  중국 우한시  해외 접촉    서울의료원(퇴원)
# 2618     3      6  1.30.  종로구       -  #3 접촉  서울대학교병원(퇴원)
# 2619     2      5  1.30.  중랑구  중국 우한시  해외 접촉    서울의료원(퇴원)
# 2620     1      2  1.24.  강서구  중국 우한시  해외 접촉  국립중앙의료원(퇴원)
#
# [2621 rows x 7 columns]

# %%
table[6].head()
# Out:
#      연번     환자    확진일  거주지 여행력   접촉력 조치사항
# 0  2621  16421  8.20.  중랑구   -  확인 중  배정중
# 1  2620  16393  8.20.   기타   -  확인 중  배정중
# 2  2619  16633  8.20.  동작구   -  확인 중  배정중
# 3  2618    미부여  8.20.  종로구   -    기타  배정중
# 4  2617  16643  8.20.  강북구   -  확인 중  배정중

# %%
df = table[6]
df.shape
# Out:
# (2621, 7)

# %%
# 미리보기 
df.head()
# Out:
#      연번     환자    확진일  거주지 여행력   접촉력 조치사항
# 0  2621  16421  8.20.  중랑구   -  확인 중  배정중
# 1  2620  16393  8.20.   기타   -  확인 중  배정중
# 2  2619  16633  8.20.  동작구   -  확인 중  배정중
# 3  2618    미부여  8.20.  종로구   -    기타  배정중
# 4  2617  16643  8.20.  강북구   -  확인 중  배정중

# %%
# 판다스 인덱스로 가져오기 
df.loc[0] # 행 0번의 자료만 뽑기
# Out:
# 연번       2621
# 환자      16421
# 확진일     8.20.
# 거주지       중랑구
# 여행력         -
# 접촉력      확인 중
# 조치사항      배정중
# Name: 0, dtype: object

# %%
# 마지막 확진일을 파일명에 써주기 위해 , 을 _로 변경 
# 확장자와 구분하기 쉽게 _로 변경 
last_day = df.loc[0, "확진일"] 
last_day
# Out:
# '8.20.'

# %%
# 마지막 확진일을 파일명에 써주기 위해 , 을 _로 변경 
# 확장자와 구분하기 쉽게 _로 변경 
last_day = df.loc[0, "확진일"]
last_day = last_day.replace(".","_")
last_day
# 파일명 자동화 8.20. >> 8_2_ 변경
# Out:
# '8_20_'

# %%
# 파일명 만들기
file_name = f""
file_name
# Out:
# ''

# %%
# 파일명 만들기
file_name = f"seoul_covil_{last_day}.csv"
file_name
# Out:
# 'seoul_covil_8_20_.csv'

# %%
# csv 파일로 저장 
df.to_csv(file_name)

# %%
pd.read_csv(file_name)
# unnamed: 0 생김
# Out:
#       Unnamed: 0    연번     환자    확진일  거주지     여행력    접촉력         조치사항
# 0              0  2621  16421  8.20.  중랑구       -   확인 중          배정중
# 1              1  2620  16393  8.20.   기타       -   확인 중          배정중
# 2              2  2619  16633  8.20.  동작구       -   확인 중          배정중
# 3              3  2618    미부여  8.20.  종로구       -     기타          배정중
# 4              4  2617  16643  8.20.  강북구       -   확인 중          배정중
# ...          ...   ...    ...    ...  ...     ...    ...          ...
# 2616        2616     5      9  1.31.  성북구       -  #5 접촉    서울의료원(퇴원)
# 2617        2617     4      7  1.30.  마포구  중국 우한시  해외 접촉    서울의료원(퇴원)
# 2618        2618     3      6  1.30.  종로구       -  #3 접촉  서울대학교병원(퇴원)
# 2619        2619     2      5  1.30.  중랑구  중국 우한시  해외 접촉    서울의료원(퇴원)
# 2620        2620     1      2  1.24.  강서구  중국 우한시  해외 접촉  국립중앙의료원(퇴원)
#
# [2621 rows x 8 columns]

# %%
# csv 파일로 저장 
df.to_csv(file_name, index=False)

# %%
# csv 파일로 저장 
df.to_csv(file_name, index=False,encoding="utf8") # cp949

# %%
pd.read_csv(file_name, encoding = "utf8")
# Out:
#         연번     환자    확진일  거주지     여행력    접촉력         조치사항
# 0     2621  16421  8.20.  중랑구       -   확인 중          배정중
# 1     2620  16393  8.20.   기타       -   확인 중          배정중
# 2     2619  16633  8.20.  동작구       -   확인 중          배정중
# 3     2618    미부여  8.20.  종로구       -     기타          배정중
# 4     2617  16643  8.20.  강북구       -   확인 중          배정중
# ...    ...    ...    ...  ...     ...    ...          ...
# 2616     5      9  1.31.  성북구       -  #5 접촉    서울의료원(퇴원)
# 2617     4      7  1.30.  마포구  중국 우한시  해외 접촉    서울의료원(퇴원)
# 2618     3      6  1.30.  종로구       -  #3 접촉  서울대학교병원(퇴원)
# 2619     2      5  1.30.  중랑구  중국 우한시  해외 접촉    서울의료원(퇴원)
# 2620     1      2  1.24.  강서구  중국 우한시  해외 접촉  국립중앙의료원(퇴원)
#
# [2621 rows x 7 columns]

# %%
df = df.sort_values(["연번"])
df.head()
# Out:
#       연번 환자    확진일  거주지     여행력    접촉력         조치사항
# 2620   1  2  1.24.  강서구  중국 우한시  해외 접촉  국립중앙의료원(퇴원)
# 2619   2  5  1.30.  중랑구  중국 우한시  해외 접촉    서울의료원(퇴원)
# 2618   3  6  1.30.  종로구       -  #3 접촉  서울대학교병원(퇴원)
# 2617   4  7  1.30.  마포구  중국 우한시  해외 접촉    서울의료원(퇴원)
# 2616   5  9  1.31.  성북구       -  #5 접촉    서울의료원(퇴원)

# %%
df = df.sort_values(["연번"], ascending=False)# 역순 ; 최신 데이터부터 출력

# %%
df.head()
# Out:
#      연번     환자    확진일  거주지 여행력   접촉력 조치사항
# 0  2621  16421  8.20.  중랑구   -  확인 중  배정중
# 1  2620  16393  8.20.   기타   -  확인 중  배정중
# 2  2619  16633  8.20.  동작구   -  확인 중  배정중
# 3  2618    미부여  8.20.  종로구   -    기타  배정중
# 4  2617  16643  8.20.  강북구   -  확인 중  배정중

# %%
df.tail()
# Out:
#       연번 환자    확진일  거주지     여행력    접촉력         조치사항
# 2616   5  9  1.31.  성북구       -  #5 접촉    서울의료원(퇴원)
# 2617   4  7  1.30.  마포구  중국 우한시  해외 접촉    서울의료원(퇴원)
# 2618   3  6  1.30.  종로구       -  #3 접촉  서울대학교병원(퇴원)
# 2619   2  5  1.30.  중랑구  중국 우한시  해외 접촉    서울의료원(퇴원)
# 2620   1  2  1.24.  강서구  중국 우한시  해외 접촉  국립중앙의료원(퇴원)
